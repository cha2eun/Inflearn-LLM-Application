# %% [markdown]
# # 1. 패키지 설치

# %%
# %pip install -q python-dotenv langchain-community
# Out:
# [notice] A new release of pip available: 22.3 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 2. LLM 답변 생성
#
# - `ChatOllama` 를 활용한 LLM 답변 생성
# - 터미널에서 `ollama pull gemma2` 와 같이 원하는 모델을 가져와야 실행 가능

# %%
from langchain_community.chat_models import ChatOllama

llm = ChatOllama(model="llama3")
# Out:
# /var/folders/dm/wtbh74jn3wz_s6cmdq8958y40000gn/T/ipykernel_32734/2342230918.py:3: LangChainDeprecationWarning: The class `ChatOllama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import ChatOllama``.
#   llm = ChatOllama(model="llama3")

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요? 한국어로 답해주세요.")

# %%
ai_message.content
# Out:
# '😊\n\n인프런(Infinite Learning)에는 다음과 같은 강의들이 있습니다.\n\n1. **Python** : 파이썬 프로그래밍, 데이터 분석, 웹 개발 등 다양한 주제의 강좌를 제공합니다.\n2. **Machine Learning** : 인공 지능, 딥 러닝, 자연어 처리, 컴퓨터 비전 등의 주제의 강좌를 제공합니다.\n3. **Data Science** : 데이터 과학, 데이터 분석, 데이터 시각화, 머신 러닝 등 다양한 주제의 강좌를 제공합니다.\n4. **Web Development** : 웹 개발, Front-end, Back-end, Full-stack 등 다양한 주제의 강좌를 제공합니다.\n5. **Artificial Intelligence** : 인공 지능, 딥 러닝, 자연어 처리, 컴퓨터 비전 등의 주제의 강좌를 제공합니다.\n6. **Cyber Security** : 사이버 보안, 네트워크 보안, 데이터 보호 등 다양한 주제의 강좌를 제공합니다.\n7. **Database** : 데이터베이스, SQL, NoSQL, 데이터 모델링 등 다양한 주제의 강좌를 제공합니다.\n8. **Operating System** : 운영 체제, Linux, Windows, macOS 등의 주제의 강좌를 제공합니다.\n9. **Mathematics** : 수학, 선형 대수, 가능성论, 통계 분석 등의 주제의 강좌를 제공합니다.\n10. **Business** : 경영, 마케팅, 회계, 인사 관리 등 다양한 주제의 강좌를 제공합니다.\n\n이 외에도 다양한 주제의 강좌가 있으니,具体적으로 관심 있는 주제를 찾아보세요! 📚'
